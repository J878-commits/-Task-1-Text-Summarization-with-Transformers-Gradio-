# %% [markdown]
# <a href="https://colab.research.google.com/github/J878-commits/-Task-1-Text-Summarization-with-Transformers-Gradio-/blob/main/%F0%9F%9A%80_Project_Title_%E2%80%9CImage_Classifier_with_CNN_%E2%80%93_Task_2_CodTech_Internship%E2%80%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🔧 Framework: TensorFlow (Keras API)

# %% [markdown]
# 📁 Project Structure in Colab

# %% [markdown]
# 🛠️ Refined Code to Improve Clarity

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the uploaded image
img = Image.open("Gemini_Generated_Image_uv0j1juv0j1juv0j.png").convert('RGB')
img_resized = img.resize((32, 32))
img_array = np.array(img_resized) / 255.0
img_array = img_array.reshape(1, 32, 32, 3)

# Predict
prediction = model.predict(img_array)
predicted_class = np.argmax(prediction)
confidence = np.max(prediction)

# CIFAR-10 class labels
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Display image and prediction
plt.imshow(img)
plt.title(f"Predicted: {class_names[predicted_class]} ({confidence:.2f} confidence)")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %% [markdown]
# Based on the code and outputs, here's a summary of the task:
#
# Summary of the Task:
#
# The code performs image classification using a pre-trained model (likely trained on the CIFAR-10 dataset, given the class names). It loads an image, preprocesses it to match the expected input size (32x32 pixels) and format of the model, and then uses the model to predict the class of the image. Finally, it displays the image with the predicted class and the confidence of the prediction.
#
# Why Upload an Image Instead of Using a Dataset:
#
# Uploading a single image directly from your laptop allows for quick and easy testing of the trained model on a specific, individual image of your choice. This is useful for:
#
# Immediate testing: You can see how the model performs on an image you're interested in right away without needing to set up a full dataset loading pipeline.
# Demonstration: It's a straightforward way to demonstrate the model's capability on a single example.
# Troubleshooting: If you're having issues with a specific image, you can quickly test it with this method.
# Using a full dataset is necessary for training and evaluating the model's performance on a large and diverse set of images, but for a quick test on a single image, uploading is more convenient.
#
# Insight for the Outcome:
#
# The output shows that the model predicted the image as a "truck" with a confidence of 0.60. The image itself is a rather unusual and complex one, featuring a llama on a motorbike with a person and various scientific diagrams in the background.
#
# The fact that the model predicted "truck" with moderate confidence (0.60) suggests:
#
# The model might be picking up on some visual features in the image that are similar to those found in trucks within the CIFAR-10 dataset. This could be related to the shape of the motorbike, the background, or other elements.
# The image is clearly not a standard "truck" image from the CIFAR-10 dataset, which is likely why the confidence is not very high. Pre-trained models are often limited by the data they were trained on, and they may struggle with images that are significantly different from that data.
# This highlights the importance of having diverse and representative training data for a model to perform well on real-world images. The model is essentially trying to fit this unusual image into one of the 10 categories it knows, and "truck" was the closest match it could find based on the features it detected.
# In summary, the code provides a quick way to test the model on a custom image, and the outcome demonstrates how the model might classify images that are outside of its training distribution.

# %% [markdown]
# 📝 Internship Task 2 Summary – CodTech Data Science Internship
#
# Task Title: Deep Learning Model for Image Classification Framework Used: TensorFlow (Keras API) Platform: Google Colab Model Type: Convolutional Neural Network (CNN) Dataset: CIFAR-10 (preloaded via tf.keras.datasets) Custom Input: Locally uploaded image for prediction
#
# 🔍 Objective:
# To implement a functional deep learning model for image classification using TensorFlow or PyTorch, with visualizations of training results and sample predictions.
#
# ⚙️ Execution Highlights:
# Designed and trained a CNN model on the CIFAR-10 dataset, comprising 10 image classes such as airplane, cat, truck, and ship.
#
# Normalized and preprocessed image data for optimal model performance.
#
# Visualized training and validation accuracy using Matplotlib.
#
# Enabled real-time prediction by uploading a custom image from the local system, resizing and formatting it to match model input.
#
# Displayed predicted class label and confidence score alongside the uploaded image.
#
# 🧠 Adaptation & Resilience:
# Originally planned to implement a “Plant Disease Detector” using the PlantVillage dataset and MobileNet architecture. Due to system RAM limitations and runtime crashes, the project was adapted to use CIFAR-10 and a locally uploaded image for classification—demonstrating flexibility and problem-solving under constraints.
#
# 📊 Deliverables:
# ✅ Functional CNN model
#
# ✅ Accuracy visualization
#
# ✅ Custom image prediction
#
# ✅ Confidence score display
#
# ✅ Colab notebook with clean, modular code
#
# 🎯 Outcome:
# Successfully completed Task 2 with a working deep learning model and visual outputs, fulfilling internship requirements. The project showcases practical implementation, adaptability, and readiness for real-world deployment scenarios.
