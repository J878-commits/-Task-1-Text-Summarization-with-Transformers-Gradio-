# %% [markdown]
# <a href="https://colab.research.google.com/github/J878-commits/-Task-1-Text-Summarization-with-Transformers-Gradio-/blob/main/Task_4_AR_VR_Interface_Design_for_Financial_Literacy_Arcade_%E2%80%93_CodTech_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fe6fa424-1a28-4b0d-84d1-199ec9501641" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe6fa424-1a28-4b0d-84d1-199ec9501641">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from IPython.display import Image, display

# If you renamed the file:
display(Image(filename='Firefly_-Isometric VR arcade interface with glowing tiles, futuristic icons, and neon lightin 779254.jpg'))

# OR if you're using the original filename:
display(Image(filename='Firefly_-Isometric VR arcade interface with glowing tiles, futuristic icons, and neon lightin 779254.jpg'))

# %% [markdown]
# 🧩 Next Steps: Build the Full Storyboard in Colab
# ✅ 1. Add Markdown Cells for Each Module

# %%
from IPython.display import Image, display
display(Image(filename='Firefly_-Isometric VR arcade interface with glowing tiles, futuristic icons, and neon lightin 779254.jpg'))  # Replace with your actual filename

# %% [markdown]
# 🟩 Credit Quest – Markdown Panel

# %% [markdown]
# ## 🟩 Credit Quest
# 🔍 Navigate a virtual maze of financial decisions
# 📈 Credit score meter reacts to each choice
# 👾 Avoid the Credit Goblin and unlock the “Credit Badge”
# 🗣️ Voiceover: “Every choice counts—how well do you know your credit?”
#
# ![Credit Quest](Firefly_-Isometric VR arcade interface with glowing tiles, futuristic icons, and neon lightin 779254.jpg)

# %% [markdown]
# ## 🟨 Savings Sprint
# ⏱️ Race against time to build savings through smart choices
# 🏦 Choose jars like “Emergency Fund,” “Vacation,” “Impulse Buy”
# 🎉 Earn the “Savings Champion” badge
# 🗣️ Voiceover: “Can you save ₹500 before the clock runs out?”
#
# ![Savings Sprint](Firefly_-Isometric VR arcade interface with glowing tiles, futuristic icons, and neon lightin 779254.jpg)  <!-- Replace with your actual filename -->

# %% [markdown]
# 🧪 Optional Widget: Simulate a Savings Choice

# %%
import ipywidgets as widgets

savings_choice = widgets.SelectMultiple(
    options=['Emergency Fund', 'Vacation', 'Impulse Buy', 'Health Savings'],
    description='Choose jars:',
    style={'description_width': 'initial'}
)
display(savings_choice)
# Out:
# SelectMultiple(description='Choose jars:', options=('Emergency Fund', 'Vacation', 'Impulse Buy', 'Health Savin…

# %% [markdown]
# 🟪 Summary & Rewards

# %% [markdown]
# ## 🟪 Summary & Rewards
# 📊 Dashboard shows earned badges, score breakdown, and personalized tips
# 🔁 Option to replay modules or share results
# 🎖️ Badges: Budget Master, Credit Navigator, Savings Champion
# 🗣️ Voiceover: “Financial literacy unlocked. Ready to level up?”
#
# ![Summary Panel](Firefly_-Isometric VR arcade interface with glowing tiles, futuristic icons, and neon lightin 779254.jpg)  <!-- Replace with your actual filename -->

# %% [markdown]
# 📄 Final Internship Summary Cell

# %% [markdown]
# ## 🎯 Internship Task-4 Summary – CodTech
# - ✅ Project: Financial Literacy Arcade
# - 🎮 Modules: Budget Battle Arena, Credit Quest, Savings Sprint
# - 🎨 Tools Used: Adobe Firefly, Colab, ipywidgets
# - 📦 Deliverables: Mockups, storyboard panels, interaction simulation
# - 🏁 Status: Completed and ready for submission
# - 📤 Portfolio: Demo-ready visuals and scrollable Colab notebook

# %% [markdown]
# 📝 Internship Submission Paragraph
# Task-4: Financial Literacy Arcade — Final Submission
#
# For Task-4 of my CodTech internship, I designed and prototyped a modular, game-based learning experience titled Financial Literacy Arcade. This interactive prototype includes three core modules—Credit Quest, Savings Sprint, and a personalized Summary & Rewards Dashboard—each crafted to teach financial concepts through immersive storytelling and intuitive gameplay. Using Adobe Firefly for mockups, Colab for storyboard narration, and ipywidgets for interaction simulation, I created a scrollable, demo-ready notebook that blends visual design with scenario-driven learning. The project emphasizes clarity, engagement, and empowerment, aligning with the internship’s goals of intuitive AR/VR interface design. All deliverables are complete and ready for portfolio inclusion.
