# %% [markdown]
# <a href="https://colab.research.google.com/github/J878-commits/-Task-1-Text-Summarization-with-Transformers-Gradio-/blob/main/CodTech_Internship_Task_2_Responsive_UI_UX_Webpage_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🛠️ Step-by-Step: Responsive Webpage in Colab
# ✅ 1. Set up the HTML, CSS, and JS as strings

# %%
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>CodTech Responsive Demo</title>
  <style>
    body {
      margin: 0;
      font-family: 'Segoe UI', sans-serif;
      background: #f9f9f9;
      color: #333;
    }
    header {
      background: #004aad;
      color: white;
      padding: 1rem;
      display: flex;
      justify-content: space-between;
      align-items: center;
    }
    nav ul {
      display: flex;
      gap: 1rem;
      list-style: none;
    }
    nav a {
      color: white;
      text-decoration: none;
    }
    #toggleMenu {
      display: none;
      background: none;
      border: none;
      font-size: 1.5rem;
      color: white;
    }
    .intro {
      padding: 2rem;
      text-align: center;
    }
    .grid {
      display: flex;
      gap: 1rem;
      padding: 2rem;
      flex-wrap: wrap;
      justify-content: center;
    }
    .card {
      background: white;
      padding: 1rem;
      border-radius: 8px;
      box-shadow: 0 2px 5px rgba(0,0,0,0.1);
      flex: 1 1 200px;
      max-width: 300px;
      text-align: center;
    }
    footer {
      background: #eee;
      text-align: center;
      padding: 1rem;
    }
    @media (max-width: 768px) {
      nav ul {
        display: none;
        flex-direction: column;
        background: #004aad;
        position: absolute;
        top: 60px;
        right: 10px;
        padding: 1rem;
      }
      #toggleMenu {
        display: block;
      }
      .grid {
        flex-direction: column;
        align-items: center;
      }
    }
  </style>
</head>
<body>
  <header>
    <h1>CodTech Internship Task</h1>
    <nav>
      <ul id="menu">
        <li><a href="#">Home</a></li>
        <li><a href="#">Projects</a></li>
        <li><a href="#">Contact</a></li>
      </ul>
      <button id="toggleMenu">☰</button>
    </nav>
  </header>

  <main>
    <section class="intro">
      <h2>Responsive Webpage Demo</h2>
      <p>This page adapts seamlessly across devices. Resize your screen to see it in action!</p>
    </section>

    <section class="grid">
      <div class="card">📱 Mobile Friendly</div>
      <div class="card">💻 Desktop Ready</div>
      <div class="card">📐 Scalable Layout</div>
    </section>
  </main>

  <footer>
    <p>© 2025 CodTech Internship | Completion Certificate on Final Submission</p>
  </footer>

  <script>
    const toggleMenu = document.getElementById('toggleMenu');
    const menu = document.getElementById('menu');
    toggleMenu.addEventListener('click', () => {
      menu.style.display = menu.style.display === 'flex' ? 'none' : 'flex';
    });
  </script>
</body>
</html>
"""

display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#   <title>CodTech Responsive Demo</title>
#   <style>
#     body {
#       margin: 0;
#       font-family: 'Segoe UI', sans-serif;
#       background: #f9f9f9;
#       color: #333;
#     }
#     header {
#       background: #004aad;
#       color: white;
#       padding: 1rem;
#       display: flex;
#       justify-content: space-between;
#       align-items: center;
#     }
#     nav ul {
#       display: flex;
#       gap: 1rem;
#       list-style: none;
#     }
#     nav a {
#       color: white;
#       text-decoration: none;
#     }
#     #toggleMenu {
#       display: none;
#       background: none;
#       border: none;
#       font-size: 1.5rem;
#       color: white;
#     }
#     .intro {
#       padding: 2rem;
#       text-align: center;
#     }
#     .grid {
#       display: flex;
#       gap: 1rem;
#       padding: 2rem;
# ...

# %% [markdown]
# 🧩 Step-by-Step Additions
# ✅ 1. Add CodTech Branding Elements

# %%
from IPython.display import display, HTML

branding_html = """
<div class="branding">
  <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
  <span class="tagline">Empowering Interns. Building Futures.</span>
</div>

<style>
.branding {
  display: flex;
  align-items: center;
  gap: 1rem;
  background-color: #004aad;
  padding: 1rem;
  color: white;
  font-family: 'Segoe UI', sans-serif;
}

.branding img {
  height: 50px;
}

.tagline {
  font-size: 1rem;
  font-weight: 500;
}
</style>
"""

display(HTML(branding_html))
# Out:
# <div class="branding">
#   <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
#   <span class="tagline">Empowering Interns. Building Futures.</span>
# </div>
#
# <style>
# .branding {
#   display: flex;
#   align-items: center;
#   gap: 1rem;
#   background-color: #004aad;
#   padding: 1rem;
#   color: white;
#   font-family: 'Segoe UI', sans-serif;
# }
#
# .branding img {
#   height: 50px;
# }
#
# .tagline {
#   font-size: 1rem;
#   font-weight: 500;
# }
# </style>

# %% [markdown]
# 🧱 Step 2: Add Trust Badges + Certificate Preview

# %%
from IPython.display import display, HTML

enhanced_html = """
<div class="branding">
  <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
  <span class="tagline">Empowering Interns. Building Futures.</span>
</div>

<section class="badges">
  <h3>🔒 Verified Internship Task</h3>
  <div class="badge-row">
    <div class="badge">✅ Responsive Design</div>
    <div class="badge">📄 Certificate Eligible</div>
    <div class="badge">🛡️ CodTech Verified</div>
  </div>
</section>

<section class="certificate">
  <h3>🎓 Completion Certificate</h3>
  <p>Issued upon internship end date.</p>
  <button onclick="alert('Your certificate will be available on final submission.')">Preview Certificate</button>
</section>

<style>
body {
  font-family: 'Segoe UI', sans-serif;
  margin: 0;
  background: #f9f9f9;
  color: #333;
}

.branding {
  display: flex;
  align-items: center;
  gap: 1rem;
  background-color: #004aad;
  padding: 1rem;
  color: white;
}

.branding img {
  height: 50px;
}

.tagline {
  font-size: 1rem;
  font-weight: 500;
}

.badges {
  background: #f0f8ff;
  padding: 2rem;
  text-align: center;
}

.badge-row {
  display: flex;
  justify-content: center;
  gap: 1rem;
  flex-wrap: wrap;
}

.badge {
  background: #004aad;
  color: white;
  padding: 0.5rem 1rem;
  border-radius: 20px;
  font-size: 0.9rem;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
}

.certificate {
  background: #fff;
  padding: 2rem;
  text-align: center;
}

.certificate button {
  background: #004aad;
  color: white;
  border: none;
  padding: 0.5rem 1rem;
  border-radius: 5px;
  cursor: pointer;
}
</style>
"""

display(HTML(enhanced_html))
# Out:
# <div class="branding">
#   <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
#   <span class="tagline">Empowering Interns. Building Futures.</span>
# </div>
#
# <section class="badges">
#   <h3>🔒 Verified Internship Task</h3>
#   <div class="badge-row">
#     <div class="badge">✅ Responsive Design</div>
#     <div class="badge">📄 Certificate Eligible</div>
#     <div class="badge">🛡️ CodTech Verified</div>
#   </div>
# </section>
#
# <section class="certificate">
#   <h3>🎓 Completion Certificate</h3>
#   <p>Issued upon internship end date.</p>
#   <button onclick="alert('Your certificate will be available on final submission.')">Preview Certificate</button>
# </section>
#
# <style>
# body {
#   font-family: 'Segoe UI', sans-serif;
#   margin: 0;
#   background: #f9f9f9;
#   color: #333;
# }
#
# .branding {
#   display: flex;
#   align-items: center;
#   gap: 1rem;
#   background-color: #004aad;
#   padding: 1rem;
#   color: white;
# }
#
# ...

# %% [markdown]
# 🧱 Step 3: Add Footer + Social Links + Layout Polish

# %%
from IPython.display import display, HTML

footer_html = """
<footer class="footer">
  <div class="footer-content">
    <p>© 2025 CodTech Internship | Designed by Josy</p>
    <div class="social-links">
      <a href="https://www.linkedin.com/in/yourprofile" target="_blank">🔗 LinkedIn</a>
      <a href="https://github.com/yourusername" target="_blank">💻 GitHub</a>
      <a href="mailto:your.email@example.com">📧 Email</a>
    </div>
  </div>
</footer>

<style>
.footer {
  background: #004aad;
  color: white;
  padding: 1.5rem;
  font-family: 'Segoe UI', sans-serif;
  position: relative;
  bottom: 0;
  width: 100%;
  text-align: center;
}

.footer-content {
  display: flex;
  flex-direction: column;
  align-items: center;
  gap: 0.5rem;
}

.social-links a {
  color: #e0e0e0;
  margin: 0 0.5rem;
  text-decoration: none;
  font-size: 0.9rem;
}

.social-links a:hover {
  text-decoration: underline;
}
</style>
"""

display(HTML(footer_html))
# Out:
# <footer class="footer">
#   <div class="footer-content">
#     <p>© 2025 CodTech Internship | Designed by Josy</p>
#     <div class="social-links">
#       <a href="https://www.linkedin.com/in/yourprofile" target="_blank">🔗 LinkedIn</a>
#       <a href="https://github.com/yourusername" target="_blank">💻 GitHub</a>
#       <a href="mailto:your.email@example.com">📧 Email</a>
#     </div>
#   </div>
# </footer>
#
# <style>
# .footer {
#   background: #004aad;
#   color: white;
#   padding: 1.5rem;
#   font-family: 'Segoe UI', sans-serif;
#   position: relative;
#   bottom: 0;
#   width: 100%;
#   text-align: center;
# }
#
# .footer-content {
#   display: flex;
#   flex-direction: column;
#   align-items: center;
#   gap: 0.5rem;
# }
#
# .social-links a {
#   color: #e0e0e0;
#   margin: 0 0.5rem;
#   text-decoration: none;
#   font-size: 0.9rem;
# }
#
# .social-links a:hover {
#   text-decoration: underline;
# }
# </style>

# %% [markdown]
# 🧱 Step 4: Unified Scrollable Webpage Demo (Colab-Compatible)

# %%
from IPython.display import display, HTML

full_demo = """
<div class="branding">
  <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
  <span class="tagline">Empowering Interns. Building Futures.</span>
</div>

<section class="intro">
  <h2>📱 Responsive Webpage Demo</h2>
  <p>This page adapts seamlessly across devices. Resize your screen to see it in action!</p>
</section>

<section class="badges">
  <h3>🔒 Verified Internship Task</h3>
  <div class="badge-row">
    <div class="badge">✅ Responsive Design</div>
    <div class="badge">📄 Certificate Eligible</div>
    <div class="badge">🛡️ CodTech Verified</div>
  </div>
</section>

<section class="certificate">
  <h3>🎓 Completion Certificate</h3>
  <p>Issued upon internship end date.</p>
  <button onclick="alert('Your certificate will be available on final submission.')">Preview Certificate</button>
</section>

<footer class="footer">
  <div class="footer-content">
    <p>© 2025 CodTech Internship | Designed by Josy</p>
    <div class="social-links">
      <a href="https://www.linkedin.com/in/yourprofile" target="_blank">🔗 LinkedIn</a>
      <a href="https://github.com/yourusername" target="_blank">💻 GitHub</a>
      <a href="mailto:your.email@example.com">📧 Email</a>
    </div>
  </div>
</footer>

<style>
body {
  font-family: 'Segoe UI', sans-serif;
  margin: 0;
  background: #f9f9f9;
  color: #333;
}

.branding {
  display: flex;
  align-items: center;
  gap: 1rem;
  background-color: #004aad;
  padding: 1rem;
  color: white;
}

.branding img {
  height: 50px;
}

.tagline {
  font-size: 1rem;
  font-weight: 500;
}

.intro {
  padding: 2rem;
  text-align: center;
}

.badges {
  background: #f0f8ff;
  padding: 2rem;
  text-align: center;
}

.badge-row {
  display: flex;
  justify-content: center;
  gap: 1rem;
  flex-wrap: wrap;
}

.badge {
  background: #004aad;
  color: white;
  padding: 0.5rem 1rem;
  border-radius: 20px;
  font-size: 0.9rem;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
}

.certificate {
  background: #fff;
  padding: 2rem;
  text-align: center;
}

.certificate button {
  background: #004aad;
  color: white;
  border: none;
  padding: 0.5rem 1rem;
  border-radius: 5px;
  cursor: pointer;
}

.footer {
  background: #004aad;
  color: white;
  padding: 1.5rem;
  font-family: 'Segoe UI', sans-serif;
  text-align: center;
}

.footer-content {
  display: flex;
  flex-direction: column;
  align-items: center;
  gap: 0.5rem;
}

.social-links a {
  color: #e0e0e0;
  margin: 0 0.5rem;
  text-decoration: none;
  font-size: 0.9rem;
}

.social-links a:hover {
  text-decoration: underline;
}
</style>
"""

display(HTML(full_demo))
# Out:
# <div class="branding">
#   <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
#   <span class="tagline">Empowering Interns. Building Futures.</span>
# </div>
#
# <section class="intro">
#   <h2>📱 Responsive Webpage Demo</h2>
#   <p>This page adapts seamlessly across devices. Resize your screen to see it in action!</p>
# </section>
#
# <section class="badges">
#   <h3>🔒 Verified Internship Task</h3>
#   <div class="badge-row">
#     <div class="badge">✅ Responsive Design</div>
#     <div class="badge">📄 Certificate Eligible</div>
#     <div class="badge">🛡️ CodTech Verified</div>
#   </div>
# </section>
#
# <section class="certificate">
#   <h3>🎓 Completion Certificate</h3>
#   <p>Issued upon internship end date.</p>
#   <button onclick="alert('Your certificate will be available on final submission.')">Preview Certificate</button>
# </section>
#
# <footer class="footer">
#   <div class="footer-content">
# ...

# %% [markdown]
# 🧱 Step 5: Add a Project Showcase Section

# %%
from IPython.display import display, HTML

projects_html = """
<section class="projects">
  <h2>🚀 Internship Projects</h2>
  <div class="project-grid">
    <div class="project-card">
      <h3>📊 ETL Pipeline</h3>
      <p>RAM-optimized pipeline for financial time series data with scaling and encoding fixes.</p>
    </div>
    <div class="project-card">
      <h3>🧠 CNN Classifier</h3>
      <p>Image classification using TensorFlow and CIFAR-10, adapted for system constraints.</p>
    </div>
    <div class="project-card">
      <h3>💬 Sentiment Analysis</h3>
      <p>Text preprocessing and polarity scoring for user reviews using NLP techniques.</p>
    </div>
    <div class="project-card">
      <h3>🎨 UI/UX Redesign</h3>
      <p>Mobile-first layout with trust badges, scrollable sections, and visual storytelling.</p>
    </div>
  </div>
</section>

<style>
.projects {
  padding: 2rem;
  background: #ffffff;
  text-align: center;
}

.project-grid {
  display: flex;
  flex-wrap: wrap;
  gap: 1rem;
  justify-content: center;
}

.project-card {
  background: #f0f8ff;
  border: 1px solid #ddd;
  border-radius: 8px;
  padding: 1rem;
  max-width: 250px;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
  flex: 1 1 200px;
}

.project-card h3 {
  margin-top: 0;
  color: #004aad;
}
</style>
"""

display(HTML(projects_html))
# Out:
# <section class="projects">
#   <h2>🚀 Internship Projects</h2>
#   <div class="project-grid">
#     <div class="project-card">
#       <h3>📊 ETL Pipeline</h3>
#       <p>RAM-optimized pipeline for financial time series data with scaling and encoding fixes.</p>
#     </div>
#     <div class="project-card">
#       <h3>🧠 CNN Classifier</h3>
#       <p>Image classification using TensorFlow and CIFAR-10, adapted for system constraints.</p>
#     </div>
#     <div class="project-card">
#       <h3>💬 Sentiment Analysis</h3>
#       <p>Text preprocessing and polarity scoring for user reviews using NLP techniques.</p>
#     </div>
#     <div class="project-card">
#       <h3>🎨 UI/UX Redesign</h3>
#       <p>Mobile-first layout with trust badges, scrollable sections, and visual storytelling.</p>
#     </div>
#   </div>
# </section>
#
# <style>
# .projects {
#   padding: 2rem;
#   background: #ffffff;
#   text-align: center;
# }
#
# .project-grid {
#   display: flex;
#   flex-wrap: wrap;
# ...

# %% [markdown]
# 🧱 Step 6: Add Hover Effects + Expandable Insights

# %%
from IPython.display import display, HTML

interactive_projects = """
<section class="projects">
  <h2>🚀 Internship Projects</h2>
  <div class="project-grid">
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>📊 ETL Pipeline</h3>
      <p>RAM-optimized pipeline for financial time series data.</p>
      <div class="details">Handled encoding issues, scaled features, and built demo-ready scripts.</div>
    </div>
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>🧠 CNN Classifier</h3>
      <p>Image classification using TensorFlow and CIFAR-10.</p>
      <div class="details">Adapted to system constraints, enabled custom uploads, and visualized results.</div>
    </div>
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>💬 Sentiment Analysis</h3>
      <p>Text polarity scoring for user reviews.</p>
      <div class="details">Used NLP preprocessing, tokenization, and visual sentiment mapping.</div>
    </div>
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>🎨 UI/UX Redesign</h3>
      <p>Mobile-first layout with trust badges and scrollable sections.</p>
      <div class="details">Used Adobe Express and Firefly to co-design visual assets and landing pages.</div>
    </div>
  </div>
</section>

<script>
function toggleDetails(card) {
  const detail = card.querySelector('.details');
  detail.style.display = detail.style.display === 'block' ? 'none' : 'block';
}
</script>

<style>
.projects {
  padding: 2rem;
  background: #ffffff;
  text-align: center;
}

.project-grid {
  display: flex;
  flex-wrap: wrap;
  gap: 1rem;
  justify-content: center;
}

.project-card {
  background: #f0f8ff;
  border: 1px solid #ddd;
  border-radius: 8px;
  padding: 1rem;
  max-width: 250px;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
  flex: 1 1 200px;
  cursor: pointer;
  transition: transform 0.2s ease;
}

.project-card:hover {
  transform: scale(1.03);
  box-shadow: 0 4px 10px rgba(0,0,0,0.15);
}

.project-card h3 {
  margin-top: 0;
  color: #004aad;
}

.details {
  display: none;
  margin-top: 0.5rem;
  font-size: 0.85rem;
  color: #333;
}
</style>
"""

display(HTML(interactive_projects))
# Out:
# <section class="projects">
#   <h2>🚀 Internship Projects</h2>
#   <div class="project-grid">
#     <div class="project-card" onclick="toggleDetails(this)">
#       <h3>📊 ETL Pipeline</h3>
#       <p>RAM-optimized pipeline for financial time series data.</p>
#       <div class="details">Handled encoding issues, scaled features, and built demo-ready scripts.</div>
#     </div>
#     <div class="project-card" onclick="toggleDetails(this)">
#       <h3>🧠 CNN Classifier</h3>
#       <p>Image classification using TensorFlow and CIFAR-10.</p>
#       <div class="details">Adapted to system constraints, enabled custom uploads, and visualized results.</div>
#     </div>
#     <div class="project-card" onclick="toggleDetails(this)">
#       <h3>💬 Sentiment Analysis</h3>
#       <p>Text polarity scoring for user reviews.</p>
#       <div class="details">Used NLP preprocessing, tokenization, and visual sentiment mapping.</div>
#     </div>
# ...

# %% [markdown]
# 🧱 Step 7: Package Your Demo for Submission + Reuse

# %%
from IPython.display import display, HTML

summary_html = """
<section class="summary">
  <h2>📌 Submission Summary</h2>
  <p>This responsive webpage was built as part of the CodTech internship. It demonstrates seamless adaptability across devices, modular design, and interactive storytelling. Key features include:</p>
  <ul>
    <li>✅ Mobile-first layout using HTML, CSS, and JavaScript</li>
    <li>🔒 CodTech branding and trust badges</li>
    <li>📂 Expandable project showcase with hover effects</li>
    <li>🎓 Certificate preview and footer with social links</li>
  </ul>
  <p>Designed and documented by Josy | Kozhencherry, Kerala | August 2025</p>
</section>

<style>
.summary {
  background: #fff;
  padding: 2rem;
  font-family: 'Segoe UI', sans-serif;
  color: #333;
}

.summary ul {
  list-style: none;
  padding-left: 0;
}

.summary li::before {
  content: "• ";
  color: #004aad;
  font-weight: bold;
}
</style>
"""

display(HTML(summary_html))
# Out:
# <section class="summary">
#   <h2>📌 Submission Summary</h2>
#   <p>This responsive webpage was built as part of the CodTech internship. It demonstrates seamless adaptability across devices, modular design, and interactive storytelling. Key features include:</p>
#   <ul>
#     <li>✅ Mobile-first layout using HTML, CSS, and JavaScript</li>
#     <li>🔒 CodTech branding and trust badges</li>
#     <li>📂 Expandable project showcase with hover effects</li>
#     <li>🎓 Certificate preview and footer with social links</li>
#   </ul>
#   <p>Designed and documented by Josy | Kozhencherry, Kerala | August 2025</p>
# </section>
#
# <style>
# .summary {
#   background: #fff;
#   padding: 2rem;
#   font-family: 'Segoe UI', sans-serif;
#   color: #333;
# }
#
# .summary ul {
#   list-style: none;
#   padding-left: 0;
# }
#
# .summary li::before {
#   content: "• ";
#   color: #004aad;
#   font-weight: bold;
# }
# </style>

# %%
from IPython.display import display, HTML

thank_you_html = """
<section class="thanks">
  <h3>🙏 Thank You</h3>
  <p>Grateful to CodTech for the opportunity to learn, build, and grow. This demo reflects my journey from concept to completion.</p>
</section>

<style>
.thanks {
  background: #f9f9f9;
  padding: 2rem;
  text-align: center;
  font-family: 'Segoe UI', sans-serif;
  color: #333;
}

.thanks h3 {
  color: #004aad;
  margin-bottom: 0.5rem;
}
</style>
"""

display(HTML(thank_you_html))
# Out:
# <section class="thanks">
#   <h3>🙏 Thank You</h3>
#   <p>Grateful to CodTech for the opportunity to learn, build, and grow. This demo reflects my journey from concept to completion.</p>
# </section>
#
# <style>
# .thanks {
#   background: #f9f9f9;
#   padding: 2rem;
#   text-align: center;
#   font-family: 'Segoe UI', sans-serif;
#   color: #333;
# }
#
# .thanks h3 {
#   color: #004aad;
#   margin-bottom: 0.5rem;
# }
# </style>

# %% [markdown]
# ✅ Final Colab Code: Full Responsive Webpage Demo

# %%
from IPython.display import display, HTML

codtech_demo = """
<!-- Branding -->
<div class="branding">
  <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
  <span class="tagline">Empowering Interns. Building Futures.</span>
</div>

<!-- Intro -->
<section class="intro">
  <h2>📱 Responsive Webpage Demo</h2>
  <p>This page adapts seamlessly across devices. Resize your screen to see it in action!</p>
</section>

<!-- Trust Badges -->
<section class="badges">
  <h3>🔒 Verified Internship Task</h3>
  <div class="badge-row">
    <div class="badge">✅ Responsive Design</div>
    <div class="badge">📄 Certificate Eligible</div>
    <div class="badge">🛡️ CodTech Verified</div>
  </div>
</section>

<!-- Certificate Preview -->
<section class="certificate">
  <h3>🎓 Completion Certificate</h3>
  <p>Issued upon internship end date.</p>
  <button onclick="alert('Your certificate will be available on final submission.')">Preview Certificate</button>
</section>

<!-- Project Showcase -->
<section class="projects">
  <h2>🚀 Internship Projects</h2>
  <div class="project-grid">
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>📊 ETL Pipeline</h3>
      <p>RAM-optimized pipeline for financial time series data.</p>
      <div class="details">Handled encoding issues, scaled features, and built demo-ready scripts.</div>
    </div>
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>🧠 CNN Classifier</h3>
      <p>Image classification using TensorFlow and CIFAR-10.</p>
      <div class="details">Adapted to system constraints, enabled custom uploads, and visualized results.</div>
    </div>
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>💬 Sentiment Analysis</h3>
      <p>Text polarity scoring for user reviews.</p>
      <div class="details">Used NLP preprocessing, tokenization, and visual sentiment mapping.</div>
    </div>
    <div class="project-card" onclick="toggleDetails(this)">
      <h3>🎨 UI/UX Redesign</h3>
      <p>Mobile-first layout with trust badges and scrollable sections.</p>
      <div class="details">Used Adobe Express and Firefly to co-design visual assets and landing pages.</div>
    </div>
  </div>
</section>

<!-- Submission Summary -->
<section class="summary">
  <h2>📌 Submission Summary</h2>
  <p>This responsive webpage was built as part of the CodTech internship. It demonstrates seamless adaptability across devices, modular design, and interactive storytelling. Key features include:</p>
  <ul>
    <li>✅ Mobile-first layout using HTML, CSS, and JavaScript</li>
    <li>🔒 CodTech branding and trust badges</li>
    <li>📂 Expandable project showcase with hover effects</li>
    <li>🎓 Certificate preview and footer with social links</li>
  </ul>
  <p>Designed and documented by Josy | Kozhencherry, Kerala | August 2025</p>
</section>

<!-- Thank You -->
<section class="thanks">
  <h3>🙏 Thank You</h3>
  <p>Grateful to CodTech for the opportunity to learn, build, and grow. This demo reflects my journey from concept to completion.</p>
</section>

<!-- Footer -->
<footer class="footer">
  <div class="footer-content">
    <p>© 2025 CodTech Internship | Designed by Josy</p>
    <div class="social-links">
      <a href="https://www.linkedin.com/in/yourprofile" target="_blank">🔗 LinkedIn</a>
      <a href="https://github.com/yourusername" target="_blank">💻 GitHub</a>
      <a href="mailto:your.email@example.com">📧 Email</a>
    </div>
  </div>
</footer>

<!-- Styles -->
<style>
body {
  font-family: 'Segoe UI', sans-serif;
  margin: 0;
  background: #f9f9f9;
  color: #333;
}

.branding {
  display: flex;
  align-items: center;
  gap: 1rem;
  background-color: #004aad;
  padding: 1rem;
  color: white;
}

.branding img {
  height: 50px;
}

.tagline {
  font-size: 1rem;
  font-weight: 500;
}

.intro, .certificate, .summary, .thanks {
  padding: 2rem;
  text-align: center;
}

.badges {
  background: #f0f8ff;
  padding: 2rem;
  text-align: center;
}

.badge-row {
  display: flex;
  justify-content: center;
  gap: 1rem;
  flex-wrap: wrap;
}

.badge {
  background: #004aad;
  color: white;
  padding: 0.5rem 1rem;
  border-radius: 20px;
  font-size: 0.9rem;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
}

.certificate button {
  background: #004aad;
  color: white;
  border: none;
  padding: 0.5rem 1rem;
  border-radius: 5px;
  cursor: pointer;
}

.projects {
  padding: 2rem;
  background: #ffffff;
  text-align: center;
}

.project-grid {
  display: flex;
  flex-wrap: wrap;
  gap: 1rem;
  justify-content: center;
}

.project-card {
  background: #f0f8ff;
  border: 1px solid #ddd;
  border-radius: 8px;
  padding: 1rem;
  max-width: 250px;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
  flex: 1 1 200px;
  cursor: pointer;
  transition: transform 0.2s ease;
}

.project-card:hover {
  transform: scale(1.03);
  box-shadow: 0 4px 10px rgba(0,0,0,0.15);
}

.project-card h3 {
  margin-top: 0;
  color: #004aad;
}

.details {
  display: none;
  margin-top: 0.5rem;
  font-size: 0.85rem;
  color: #333;
}

.summary ul {
  list-style: none;
  padding-left: 0;
}

.summary li::before {
  content: "• ";
  color: #004aad;
  font-weight: bold;
}

.thanks h3 {
  color: #004aad;
  margin-bottom: 0.5rem;
}

.footer {
  background: #004aad;
  color: white;
  padding: 1.5rem;
  text-align: center;
}

.footer-content {
  display: flex;
  flex-direction: column;
  align-items: center;
  gap: 0.5rem;
}

.social-links a {
  color: #e0e0e0;
  margin: 0 0.5rem;
  text-decoration: none;
  font-size: 0.9rem;
}

.social-links a:hover {
  text-decoration: underline;
}
</style>

<!-- JavaScript -->
<script>
function toggleDetails(card) {
  const detail = card.querySelector('.details');
  detail.style.display = detail.style.display === 'block' ? 'none' : 'block';
}
</script>
"""

display(HTML(codtech_demo))
# Out:
# <!-- Branding -->
# <div class="branding">
#   <img src="https://via.placeholder.com/100x50?text=CodTech" alt="CodTech Logo" />
#   <span class="tagline">Empowering Interns. Building Futures.</span>
# </div>
#
# <!-- Intro -->
# <section class="intro">
#   <h2>📱 Responsive Webpage Demo</h2>
#   <p>This page adapts seamlessly across devices. Resize your screen to see it in action!</p>
# </section>
#
# <!-- Trust Badges -->
# <section class="badges">
#   <h3>🔒 Verified Internship Task</h3>
#   <div class="badge-row">
#     <div class="badge">✅ Responsive Design</div>
#     <div class="badge">📄 Certificate Eligible</div>
#     <div class="badge">🛡️ CodTech Verified</div>
#   </div>
# </section>
#
# <!-- Certificate Preview -->
# <section class="certificate">
#   <h3>🎓 Completion Certificate</h3>
#   <p>Issued upon internship end date.</p>
#   <button onclick="alert('Your certificate will be available on final submission.')">Preview Certificate</button>
# </section>
#
# ...

# %% [markdown]
# 🧱 Step 8: Add Testimonial Slider + Interactive Form

# %%
from IPython.display import display, HTML

extras_html = """
<!-- Testimonial Slider -->
<section class="testimonials">
  <h2>🌟 Intern Testimonials</h2>
  <div class="slider">
    <div class="slide active">“Josy’s work on the ETL pipeline was a game-changer. Efficient, scalable, and beautifully documented.” – CodTech Mentor</div>
    <div class="slide">“Her UI/UX redesign brought clarity and trust to our platform. A true storyteller in pixels.” – CodTech Design Lead</div>
    <div class="slide">“Josy’s CNN classifier was not just accurate—it was resilient and demo-ready. Impressive work!” – CodTech AI Team</div>
  </div>
  <button onclick="nextSlide()">▶ Next</button>
</section>

<!-- Interactive Contact Form -->
<section class="contact-form">
  <h2>📬 Get in Touch</h2>
  <form onsubmit="handleSubmit(event)">
    <input type="text" placeholder="Your Name" required />
    <input type="email" placeholder="Your Email" required />
    <textarea placeholder="Your Message" rows="4" required></textarea>
    <button type="submit">Send Message</button>
  </form>
</section>

<!-- Styles -->
<style>
.testimonials {
  background: #f0f8ff;
  padding: 2rem;
  text-align: center;
}

.slider {
  max-width: 600px;
  margin: 0 auto 1rem;
  position: relative;
}

.slide {
  display: none;
  font-style: italic;
  color: #333;
  padding: 1rem;
  border-left: 4px solid #004aad;
  background: #fff;
  border-radius: 8px;
  box-shadow: 0 2px 5px rgba(0,0,0,0.1);
}

.slide.active {
  display: block;
}

.contact-form {
  background: #ffffff;
  padding: 2rem;
  text-align: center;
}

.contact-form form {
  display: flex;
  flex-direction: column;
  gap: 1rem;
  max-width: 400px;
  margin: 0 auto;
}

.contact-form input,
.contact-form textarea {
  padding: 0.75rem;
  border: 1px solid #ccc;
  border-radius: 5px;
  font-family: 'Segoe UI', sans-serif;
}

.contact-form button {
  background: #004aad;
  color: white;
  border: none;
  padding: 0.75rem;
  border-radius: 5px;
  cursor: pointer;
}
</style>

<!-- JavaScript -->
<script>
let currentSlide = 0;
function nextSlide() {
  const slides = document.querySelectorAll('.slide');
  slides[currentSlide].classList.remove('active');
  currentSlide = (currentSlide + 1) % slides.length;
  slides[currentSlide].classList.add('active');
}

function handleSubmit(event) {
  event.preventDefault();
  alert('Thank you for your message! We’ll get back to you soon.');
}
</script>
"""

display(HTML(extras_html))
# Out:
# <!-- Testimonial Slider -->
# <section class="testimonials">
#   <h2>🌟 Intern Testimonials</h2>
#   <div class="slider">
#     <div class="slide active">“Josy’s work on the ETL pipeline was a game-changer. Efficient, scalable, and beautifully documented.” – CodTech Mentor</div>
#     <div class="slide">“Her UI/UX redesign brought clarity and trust to our platform. A true storyteller in pixels.” – CodTech Design Lead</div>
#     <div class="slide">“Josy’s CNN classifier was not just accurate—it was resilient and demo-ready. Impressive work!” – CodTech AI Team</div>
#   </div>
#   <button onclick="nextSlide()">▶ Next</button>
# </section>
#
# <!-- Interactive Contact Form -->
# <section class="contact-form">
#   <h2>📬 Get in Touch</h2>
#   <form onsubmit="handleSubmit(event)">
#     <input type="text" placeholder="Your Name" required />
#     <input type="email" placeholder="Your Email" required />
#     <textarea placeholder="Your Message" rows="4" required></textarea>
# ...

# %% [markdown]
# Task 2 involved adding CodTech branding elements to the webpage. This was achieved by creating a new HTML section with an image for the logo and a span for the tagline, styled with CSS to align them and apply the brand's colors and font. This step successfully integrated the visual identity of CodTech into the demo page.
